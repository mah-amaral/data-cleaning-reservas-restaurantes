# %% [markdown]
# # Tratamento e Padronização de Dados de Reservas
#
# Este projeto apresenta um pipeline de tratamento de dados de reservas de uma rede de bares e restaurantes, com foco em:
#
# - Padronização de unidades
# - Enriquecimento de dados cadastrais
# - Validação de integridade
# - Preparação para consumo em ferramentas de BI
#
# > ⚠️ Os nomes de marcas e unidades são utilizados exclusivamente para fins educacionais, sem representar dados operacionais reais.

# %% [markdown]
# ## 🎯 Objetivo
#
# O objetivo deste projeto é transformar uma base bruta de reservas em uma tabela final estruturada, confiável e pronta para análise, simulando um cenário real de dados operacionais no setor de food service.

# %% [markdown]
# ## 🧠 Contexto
#
# Bases de reservas costumam apresentar desafios como:
# - Nomes de unidades inconsistentes
# - Falta de padronização de colunas
# - Ausência de dados cadastrais completos
# - Dificuldade de integração com ferramentas de BI
#
# Este pipeline resolve esses problemas por meio de regras claras de transformação e validação.

# %%
# Pipeline de tratamento e enriquecimento de dados

import pandas as pd

df_reservas = pd.read_excel("data.xlsx")

# contagem original de linhas
n_orig = len(df_reservas)
print(f"Linhas originais: {n_orig}")

# dicionário para renomear siglas
mapa_unidades = {
    "Boa Praça - Barra":"BPBARRA",
    "Boa Praça - Brasília": "BPBSB",
    "Boa Praça - Curitiba":"BPCUR",
    "Boa Praça - Ipanema": "BPIPA",
    "Boa Praça - Itaim": "BPI",
    "Boa Praça - Leblon": "BPL",
    "Boa Praça - Morumbi": "BPM",
    "Boa Praça - Niterói": "BPNI",
    "Boa Praça - Paulista": "BPP",

    "Boteco Princesa - Barra": "PRINCESA BARRA",
    "Boteco Princesa - Leblon": "PRINCESA LEBLON",

    "Boteco Rainha - Barra": "RAINHA BARRA",
    "Boteco Rainha - Clodomiro Itaim": "RAINHA CLO",
    "Boteco Rainha - Goiânia": "RAINHA GOIANIA",
    "Boteco Rainha - Leblon": "RAINHA LEBLON",
    "Boteco Rainha - Paulista": "RAINHA PAULISTA",
    "Boteco Rainha - Pedroso Itaim": "RAINHA PEDROSO",

    "Da Marino - Ipanema": "DA MARINO IPANEMA",
    "Da Marino - Itaim": "DA MARINO ITAIM",
    "Da Marino - Morumbi": "DA MARINO MORUMBI",

    "Eu Tu Eles - Paulista": "ETEP",
    "Eu Tu Eles - Vila Olimpia": "ETEVO",

    "Forno da Pino": "FORNO",

    "Giulietta - Goiania": "GIULIETTA GOIÂNIA",
    "Giulietta Carni": "GIULIETTA ITAIM",

    "Irajá Redux - Barra": "IRAJÁ BARRA",
    "Irajá Redux - Rio Sul": "IRAJÁ RIO SUL",
    "Irajá Redux Leblon": "IRAJÁ LEBLON",

    "Ninetto - Belo Horizonte": "NINETTO BH",
    "Ninetto - Curitiba": "NINETTO CURITIBA",
    "Ninetto - Dom Pedro": "NINETTO CAMPINAS",
    "Ninetto - Fortaleza": "NINETTO FORTALEZA",
    "Ninetto - Recife": "NINETTO RECIFE",
    "Ninetto - Rio Design": "NINETTO BARRA",
    "Ninetto - Shopping Eldorado": "NINETTO ELDORADO",
    "Ninetto - Shopping Morumbi": "NINETTO MORUMBI",
    "Ninetto - Uberlandia": "NINETTO UBERLANDIA",

    "Nino - Belo Horizonte": "NINO BH",
    "Nino - Brasilia": "NINO BSB",
    "Nino - Goiania": "NINO GOIANIA",
    "Nino - Ipanema": "NINO IPANEMA",
    "Nino - São Paulo": "NINO ITAIM",

    "Peppino Cantina": "PEPPINO",

    "Tatu Bola - Berrini": "TBB",
    "Tatu Bola - Campinas": "TBCAMP",
    "Tatu Bola - Campo Grande": "TBCG",
    "Tatu Bola - Fortaleza": "TBF",
    "Tatu Bola - Goiania": "TBG",
    "Tatu Bola - Itaim": "TBI",
    "Tatu Bola - Jardins": "TBJ",
    "Tatu Bola - Pampulha": "TBPAMP",
    "Tatu Bola - Recife": "TBREC",
    "Tatu Bola - Ribeirão Preto": "TBRP",
    "Tatu Bola - Salvador": "TBSSA",
    "Tatu Bola - Santana": "TBZN",
    "Tatu Bola - Savassi": "TBBH",
    "Tatu Bola - Sorocaba": "TBS",
    "Tatu Bola - Tatuapé": "TBT",
    "Tatu Bola - Uberlandia": "TBUBER",
    "Tatu Bola - Vila Olimpia": "TBVO",

    "Tatuzinho - Pompéia": "TTZPOMP"
}

# normaliza strings
def normalize_text(x):
    if pd.isna(x):
        return x
    return str(x).strip()

df_reservas["Unidade_Origem"] = df_reservas["Unidade"].apply(normalize_text)
df_reservas["Sigla"] = df_reservas["Unidade_Origem"].map(mapa_unidades)

# padronização nomes col
df_reservas = df_reservas.rename(columns={
    "Nome do Cliente": "Clientes",
    "Número de Pessoas": "Quantidade de Convidados",
    "Data da Reserva": "Data Evento"
})

df_reservas = df_reservas.reindex(columns=[
    "Sigla",
    "Clientes",
    "Quantidade de Convidados",
    "Data Evento",
    "Unidade_Origem"
])


# procv para preenchimento de colunas novas
df_ref = pd.DataFrame([
    {"Sigla":"BPBARRA","Categoria":"Bar","Vertical":"Bares BR","Marca":"Boa Praça","Unidade":"Barra","Cidade":"Rio de Janeiro","Estado":"RJ","Endereço":"Av. Olegário Maciel, 214 - Barra da Tijuca, Rio de Janeiro - RJ, 22621-200"},
    {"Sigla":"BPBSB","Categoria":"Bar","Vertical":"Bares BR","Marca":"Boa Praça","Unidade":"Brasília","Cidade":"Brasília","Estado":"DF","Endereço":"Asa Sul Comércio Local Sul 201 BL C Sala 33 - Asa Sul, Brasília - DF, 70040-906"},
    {"Sigla":"BPCUR","Categoria":"Bar","Vertical":"Bares BR","Marca":"Boa Praça","Unidade":"Batel","Cidade":"Curitiba","Estado":"PR","Endereço":"R. Comendador Araújo, 1066 - Batel, Curitiba - PR, 80420-000"},
    {"Sigla":"BPI","Categoria":"Bar","Vertical":"Bares BR","Marca":"Boa Praça","Unidade":"Itaim","Cidade":"São Paulo","Estado":"SP","Endereço":"Av. Brig. Faria Lima, 3183 - Itaim Bibi, São Paulo - SP, 01453-050"},
    {"Sigla":"BPIPA","Categoria":"Bar","Vertical":"Bares BR","Marca":"Boa Praça","Unidade":"Ipanema","Cidade":"Rio de Janeiro","Estado":"RJ","Endereço":"Av. Vieira Souto, 110 - Ipanema, Rio de Janeiro - RJ, 22420-002"},
    {"Sigla":"BPL","Categoria":"Bar","Vertical":"Bares BR","Marca":"Boa Praça","Unidade":"Leblon","Cidade":"Rio de Janeiro","Estado":"RJ","Endereço":"Rua Dias Ferreira, 12 - Leblon, Rio de Janeiro - RJ, 22431-050"},
    {"Sigla":"BPM","Categoria":"Bar","Vertical":"Bares BR","Marca":"Boa Praça","Unidade":"Morumbi","Cidade":"São Paulo","Estado":"SP","Endereço":"R. Oscar Rodrigues Cajado Filho, 237 - São Paulo - SP, 04710-090"},
    {"Sigla":"BPNI","Categoria":"Bar","Vertical":"Bares BR","Marca":"Boa Praça","Unidade":"Niterói","Cidade":"Niterói","Estado":"RJ","Endereço":"R. Miguel de Frias, 236 - Icaraí, Niterói - RJ, 24220-005"},
    {"Sigla":"BPP","Categoria":"Bar","Vertical":"Bares BR","Marca":"Boa Praça","Unidade":"Paulista","Cidade":"São Paulo","Estado":"SP","Endereço":"Alameda Santos, 1873 - Jardim Paulista, São Paulo - SP, 01419-100"},

    {"Sigla":"DA MARINO BH","Categoria":"Restaurante","Vertical":"Restaurantes","Marca":"Da Marino","Unidade":"Belo Horizonte","Cidade":"Belo Horizonte","Estado":"MG","Endereço":"Rua Curitiba, 2081 - Lourdes, Belo Horizonte - MG, 30170-127"},
    {"Sigla":"DA MARINO BRASÍLIA","Categoria":"Restaurante","Vertical":"Restaurantes","Marca":"Da Marino","Unidade":"Brasília","Cidade":"Brasília","Estado":"DF","Endereço":"SHCS CLS 402 - Asa Sul, Brasília - DF, 70236-530"},
    {"Sigla":"DA MARINO IPANEMA","Categoria":"Restaurante","Vertical":"Restaurantes","Marca":"Da Marino","Unidade":"Ipanema","Cidade":"Rio de Janeiro","Estado":"RJ","Endereço":"R. Barão da Torre, 482 - Ipanema, Rio de Janeiro - RJ, 22411-002"},
    {"Sigla":"DA MARINO ITAIM","Categoria":"Restaurante","Vertical":"Restaurantes","Marca":"Da Marino","Unidade":"Itaim","Cidade":"São Paulo","Estado":"SP","Endereço":"R. Jerônimo da Veiga, 74 - Jardim Europa, São Paulo - SP, 04536-000"},
    {"Sigla":"DA MARINO MORUMBI","Categoria":"Restaurante","Vertical":"Restaurantes","Marca":"Da Marino","Unidade":"Morumbi","Cidade":"São Paulo","Estado":"SP","Endereço":"Av. Roque Petroni Júnior, 1089 - Loja 27, São Paulo - SP, 04707-900"},

    {"Sigla":"ETEP","Categoria":"Bar","Vertical":"Bares SP","Marca":"Eu Tu Eles","Unidade":"Paulista","Cidade":"São Paulo","Estado":"SP","Endereço":"Alameda Joaquim Eugênio de Lima, 612 - Jardim Paulista, São Paulo - SP, 01418-100"},
    {"Sigla":"ETEVO","Categoria":"Bar","Vertical":"Bares SP","Marca":"Eu Tu Eles","Unidade":"Vila Olímpia","Cidade":"São Paulo","Estado":"SP","Endereço":"R. Gomes de Carvalho, 1575 - Vila Olímpia, São Paulo - SP, 04547-006"},

    {"Sigla":"FORNO","Categoria":"Restaurante","Vertical":"Restaurantes","Marca":"Forno da Pino","Unidade":"Itaim","Cidade":"São Paulo","Estado":"SP","Endereço":"R. Jerônimo da Veiga, 75 - Itaim Bibi, São Paulo - SP, 04536-000"},

    {"Sigla":"GIULIETTA GOIÂNIA","Categoria":"Restaurante","Vertical":"Restaurantes","Marca":"Giulietta","Unidade":"Goiânia","Cidade":"Goiânia","Estado":"GO","Endereço":"Av T3, 2707 - St Bueno, Goiânia, 74210-245"},
    {"Sigla":"GIULIETTA ITAIM","Categoria":"Restaurante","Vertical":"Restaurantes","Marca":"Giulietta","Unidade":"Itaim","Cidade":"São Paulo","Estado":"SP","Endereço":"R. Jerônimo da Veiga, 36 - Jardim Europa, São Paulo - SP, 04536-000"},

    {"Sigla":"HAIKAI","Categoria":"Restaurante","Vertical":"Restaurantes","Marca":"Haikai","Unidade":"Goiânia","Cidade":"Goiânia","Estado":"GO","Endereço":"R. Nossa Sra. do Rosário, 28 - Centro, Pirenópolis - GO, 72980-000"},

    {"Sigla":"IRAJÁ BARRA","Categoria":"Restaurante","Vertical":"Irajá","Marca":"Irajá","Unidade":"Barra","Cidade":"Rio de Janeiro","Estado":"RJ","Endereço":"Av. das Américas, 7777 - Barra da Tijuca, Rio de Janeiro - RJ, 22793-081"},
    {"Sigla":"IRAJÁ CAMPINAS","Categoria":"Restaurante","Vertical":"Irajá","Marca":"Irajá","Unidade":"Campinas","Cidade":"Campinas","Estado":"SP","Endereço":"Av. Guilherme Campos, 500 - Jardim Santa Genebra, Campinas - SP, 13087-635"},
    {"Sigla":"IRAJÁ LEBLON","Categoria":"Restaurante","Vertical":"Irajá","Marca":"Irajá","Unidade":"Leblon","Cidade":"Rio de Janeiro","Estado":"RJ","Endereço":"Av. Ataulfo de Paiva, 270 - Leblon, Rio de Janeiro - RJ, 22440-033"},
    {"Sigla":"IRAJÁ RIO SUL","Categoria":"Restaurante","Vertical":"Irajá","Marca":"Irajá","Unidade":"Rio Sul","Cidade":"Rio de Janeiro","Estado":"RJ","Endereço":"Av. Lauro Sodré, 445 - Botafogo, Rio de Janeiro - RJ, 22290-070"},

    {"Sigla":"NINETTO BARRA","Categoria":"Restaurante","Vertical":"Restaurantes","Marca":"Ninetto","Unidade":"Rio de Janeiro","Cidade":"Rio de Janeiro","Estado":"RJ","Endereço":"Av. das Américas, 7777 - Barra, Rio de Janeiro - RJ, 22793-081"},
    {"Sigla":"NINETTO BH","Categoria":"Restaurante","Vertical":"Restaurantes","Marca":"Ninetto","Unidade":"Belo Horizonte","Cidade":"Belo Horizonte","Estado":"MG","Endereço":"BR-356, 3049 - Belo Horizonte - MG, 30320-900"},
    {"Sigla":"NINETTO CAMPINAS","Categoria":"Restaurante","Vertical":"Restaurantes","Marca":"Ninetto","Unidade":"Campinas","Cidade":"Campinas","Estado":"SP","Endereço":"Av. Guilherme Campos, 500 - R-08A - Campinas - SP, 13080-000"},
    {"Sigla":"NINETTO CURITIBA","Categoria":"Restaurante","Vertical":"Restaurantes","Marca":"Ninetto","Unidade":"Curitiba","Cidade":"Curitiba","Estado":"PR","Endereço":"R. Prof. Pedro Viriato Parigot de Souza, Curitiba - PR, 81200-100"},
    {"Sigla":"NINETTO ELDORADO","Categoria":"Restaurante","Vertical":"Restaurantes","Marca":"Ninetto","Unidade":"São Paulo","Cidade":"São Paulo","Estado":"SP","Endereço":"Av. Rebouças, 3970 - Pinheiros, São Paulo - SP, 05402-918"},
    {"Sigla":"NINETTO FORTALEZA","Categoria":"Restaurante","Vertical":"Restaurantes","Marca":"Ninetto","Unidade":"Fortaleza","Cidade":"Fortaleza","Estado":"CE","Endereço":"Av. Washington Soares, 85 - Edson Queiroz, Fortaleza - CE, 60811-341"},
    {"Sigla":"NINETTO MORUMBI","Categoria":"Restaurante","Vertical":"Restaurantes","Marca":"Ninetto","Unidade":"São Paulo","Cidade":"São Paulo","Estado":"SP","Endereço":"Av. Roque Petroni Júnior, 1089 - Morumbi, São Paulo - SP, 04707-000"},
    {"Sigla":"NINETTO RECIFE","Categoria":"Restaurante","Vertical":"Restaurantes","Marca":"Ninetto","Unidade":"Recife","Cidade":"Recife","Estado":"PE","Endereço":"Av. República do Líbano, 251 - Recife - PE, 51110-160"},
    {"Sigla":"NINETTO UBERLANDIA","Categoria":"Restaurante","Vertical":"Restaurantes","Marca":"Ninetto","Unidade":"Uberlândia","Cidade":"Uberlândia","Estado":"MG","Endereço":"Av. João Naves de Ávila, 1331 - Uberlândia - MG, 38408-902"},

    {"Sigla":"NINO BH","Categoria":"Restaurante","Vertical":"Restaurantes","Marca":"Nino","Unidade":"Belo Horizonte","Cidade":"Belo Horizonte","Estado":"MG","Endereço":"R. Curitiba, 2090 - Lourdes, Belo Horizonte - MG, 30170-127"},
    {"Sigla":"NINO BSB","Categoria":"Restaurante","Vertical":"Restaurantes","Marca":"Nino","Unidade":"Brasília","Cidade":"Brasília","Estado":"DF","Endereço":"Asa Sul CLS 403 BL D Loja 34 - Brasília - DF, 70237-500"},
    {"Sigla":"NINO GOIANIA","Categoria":"Restaurante","Vertical":"Restaurantes","Marca":"Nino","Unidade":"Goiânia","Cidade":"Goiânia","Estado":"GO","Endereço":"Avenida T3, 2707 - Setor Bueno, Goiás - GO, 74210-245"},
    {"Sigla":"NINO IPANEMA","Categoria":"Restaurante","Vertical":"Restaurantes","Marca":"Nino","Unidade":"Ipanema","Cidade":"Rio de Janeiro","Estado":"RJ","Endereço":"R. Barão da Torre, 490 - Ipanema, Rio de Janeiro - RJ, 22411-002"},
    {"Sigla":"NINO ITAIM","Categoria":"Restaurante","Vertical":"Restaurantes","Marca":"Nino","Unidade":"Itaim","Cidade":"São Paulo","Estado":"SP","Endereço":"R. Jerônimo da Veiga, 30 - Jardim Europa, São Paulo - SP, 04536-000"},

    {"Sigla":"PEPPINO","Categoria":"Restaurante","Vertical":"Restaurantes","Marca":"Peppino","Unidade":"Itaim","Cidade":"São Paulo","Estado":"SP","Endereço":"R. João Cachoeira, 175 - Itaim Bibi - São Paulo - SP, 04536-000"},

    {"Sigla":"PRINCESA BARRA","Categoria":"Bar","Vertical":"Irajá","Marca":"Princesa","Unidade":"Barra","Cidade":"Rio de Janeiro","Estado":"RJ","Endereço":"Av. das Américas, 7777 - Barra da Tijuca, Rio de Janeiro - RJ, 22793-081"},
    {"Sigla":"PRINCESA ITAIM","Categoria":"Bar","Vertical":"Irajá","Marca":"Princesa","Unidade":"Itaim","Cidade":"São Paulo","Estado":"SP","Endereço":"R. Pedroso Alvarenga, 909 - Itaim Bibi, São Paulo - SP, 04531-011"},
    {"Sigla":"PRINCESA LEBLON","Categoria":"Bar","Vertical":"Irajá","Marca":"Princesa","Unidade":"Leblon","Cidade":"Rio de Janeiro","Estado":"RJ","Endereço":"R. João Líra, 148 - Leblon, Rio de Janeiro - RJ, 22430-210"},

    {"Sigla":"RAINHA BARRA","Categoria":"Bar","Vertical":"Irajá","Marca":"Rainha","Unidade":"Rio Design Barra","Cidade":"Rio de Janeiro","Estado":"RJ","Endereço":"Av. das Américas, 7777 - Barra da Tijuca, Rio de Janeiro - RJ, 22793-081"},
    {"Sigla":"RAINHA CAMPINAS","Categoria":"Bar","Vertical":"Irajá","Marca":"Rainha","Unidade":"Campinas","Cidade":"Campinas","Estado":"SP","Endereço":"Av. Guilherme Campos, 500 - Campinas - SP, 13087-901"},
    {"Sigla":"RAINHA CLO","Categoria":"Bar","Vertical":"Irajá","Marca":"Rainha","Unidade":"Itaim","Cidade":"São Paulo","Estado":"SP","Endereço":"R. Clodomiro Amazonas, 202 - Itaim Bibi, São Paulo - SP, 04537-000"},
    {"Sigla":"RAINHA GOIANIA","Categoria":"Bar","Vertical":"Irajá","Marca":"Rainha","Unidade":"Goiânia","Cidade":"Goiânia","Estado":"GO","Endereço":"Av. Dep. Jamel Cecílio, 118 - Vila Maria José, Goiânia - GO, 74810-100"},
    {"Sigla":"RAINHA LEBLON","Categoria":"Bar","Vertical":"Irajá","Marca":"Rainha","Unidade":"Leblon","Cidade":"Rio de Janeiro","Estado":"RJ","Endereço":"Rua Dias Ferreira, 247 - Leblon, Rio de Janeiro - RJ, 22431-050"},
    {"Sigla":"RAINHA PAULISTA","Categoria":"Bar","Vertical":"Irajá","Marca":"Rainha","Unidade":"Paulista","Cidade":"São Paulo","Estado":"SP","Endereço":"Alameda Campinas, 493 - Jardim Paulista, São Paulo - SP, 01404-100"},
    {"Sigla":"RAINHA PEDROSO","Categoria":"Bar","Vertical":"Irajá","Marca":"Rainha","Unidade":"Itaim","Cidade":"São Paulo","Estado":"SP","Endereço":"R. Pedroso Alvarenga, 1177A - Itaim Bibi, São Paulo - SP, 04531-012"},

    {"Sigla":"TABERNA ITAIM","Categoria":"Restaurante","Vertical":"Restaurantes","Marca":"Rainha","Unidade":"Itaim","Cidade":"São Paulo","Estado":"SP","Endereço":"R. Jerônimo da Veiga, 129 - Jardim Europa, São Paulo - SP, 04536-000"},
    {"Sigla":"TABERNA LEBLON","Categoria":"Restaurante","Vertical":"Restaurantes","Marca":"Rainha","Unidade":"Leblon","Cidade":"Rio de Janeiro","Estado":"RJ","Endereço":"Rua Dias Ferreira, 233 - Leblon, Rio de Janeiro - RJ, 22431-050"},

    {"Sigla":"TBB","Categoria":"Bar","Vertical":"Bares SP","Marca":"Tatu Bola","Unidade":"Berrini","Cidade":"São Paulo","Estado":"SP","Endereço":"Avenida Berrini, 685 - Vila Olímpia - São Paulo - SP, 04571-000"},
    {"Sigla":"TBBH","Categoria":"Bar","Vertical":"Bares BR","Marca":"Tatu Bola","Unidade":"Belo Horizonte","Cidade":"Belo Horizonte","Estado":"MG","Endereço":"Av. do Contorno, 6557 - Savassi, Belo Horizonte - MG, 30110-043"},
    {"Sigla":"TBCAMP","Categoria":"Bar","Vertical":"Bares SP","Marca":"Tatu Bola","Unidade":"Campinas","Cidade":"Campinas","Estado":"SP","Endereço":"R. Américo Brasiliense, 328 - Cambuí, Campinas - SP, 13025-230"},
    {"Sigla":"TBCG","Categoria":"Bar","Vertical":"Bares BR","Marca":"Tatu Bola","Unidade":"Campo Grande","Cidade":"Campo Grande","Estado":"MS","Endereço":"R. Espírito Santo, 851 - Jardim dos Estados, Campo Grande - MS, 79321-788"},
    {"Sigla":"TBCUI","Categoria":"Bar","Vertical":"Bares BR","Marca":"Tatu Bola","Unidade":"Cuiabá","Cidade":"Cuiabá","Estado":"MT","Endereço":"R. Sen. Vilas Bôas, 48 - Popular - Cuiabá - MT, 78045-430"},
    {"Sigla":"TBF","Categoria":"Bar","Vertical":"Bares BR","Marca":"Tatu Bola","Unidade":"Fortaleza","Cidade":"Fortaleza","Estado":"CE","Endereço":"R. República do Líbano, 1084 - Meireles, Fortaleza - CE, 60160-140"},
    {"Sigla":"TBG","Categoria":"Bar","Vertical":"Bares BR","Marca":"Tatu Bola","Unidade":"Goiânia","Cidade":"Goiânia","Estado":"GO","Endereço":"Al. Cel. Eugênio Jardim, Goiânia - GO, 74175-100"},
    {"Sigla":"TBI","Categoria":"Bar","Vertical":"Bares SP","Marca":"Tatu Bola","Unidade":"Itaim","Cidade":"São Paulo","Estado":"SP","Endereço":"R. Clodomiro Amazonas, 260 - Itaim Bibi - São Paulo - SP, 04537-000"},
    {"Sigla":"TBJ","Categoria":"Bar","Vertical":"Bares SP","Marca":"Tatu Bola","Unidade":"Jardins","Cidade":"São Paulo","Estado":"SP","Endereço":"R. Augusta, 3000 - Jardim America - São Paulo - SP, 01412-100"},
    {"Sigla":"TBPAMP","Categoria":"Bar","Vertical":"Bares BR","Marca":"Tatu Bola","Unidade":"Pampulha","Cidade":"Belo Horizonte","Estado":"MG","Endereço":"Av. Fleming, 152 - Ouro Preto, Belo Horizonte - MG, 31310-490"},
    {"Sigla":"TBREC","Categoria":"Bar","Vertical":"Bares BR","Marca":"Tatu Bola","Unidade":"Recife","Cidade":"Recife","Estado":"PE","Endereço":"Av. Herculano Bandeira, 21 - Recife - PE, 51011-000"},

    {"Sigla":"TBRP","Categoria":"Bar","Vertical":"Bares SP","Marca":"Tatu Bola","Unidade":"Ribeirão Preto","Cidade":"Ribeirão Preto","Estado":"SP","Endereço":"Av. Itatiaia, 1214 - Jardim Sumaré, Ribeirão Preto - SP, 14025-240"},
    {"Sigla":"TBS","Categoria":"Bar","Vertical":"Bares SP","Marca":"Tatu Bola","Unidade":"Sorocaba","Cidade":"Sorocaba","Estado":"SP","Endereço":"Av. Domingos Júlio, 827 - Parque Campolim, Sorocaba - SP, 18047-645"},
    {"Sigla":"TBSB","Categoria":"Bar","Vertical":"Bares SP","Marca":"Tatu Bola","Unidade":"São Bernardo","Cidade":"São Bernardo do Campo","Estado":"SP","Endereço":"Avenida Kennedy, 1250 - São Bernardo do Campo - SP, 09726-253"},
    {"Sigla":"TBSSA","Categoria":"Bar","Vertical":"Bares BR","Marca":"Tatu Bola","Unidade":"Salvador","Cidade":"Salvador","Estado":"BA","Endereço":"Rua Guillard Muniz, 609 - Pituba, Salvador - BA, 41810-110"},
    {"Sigla":"TBT","Categoria":"Bar","Vertical":"Bares SP","Marca":"Tatu Bola","Unidade":"Tatuapé","Cidade":"São Paulo","Estado":"SP","Endereço":"R. Emília Marengo, 534 - Tatuapé - São Paulo - SP, 03336-000"},
    {"Sigla":"TBUBER","Categoria":"Bar","Vertical":"Bares BR","Marca":"Tatu Bola","Unidade":"Uberlândia","Cidade":"Uberlândia","Estado":"MG","Endereço":"Av. Francisco Galassi, 990 - Morada da Colina, Uberlândia - MG, 38411-120"},
    {"Sigla":"TBVO","Categoria":"Bar","Vertical":"Bares SP","Marca":"Tatu Bola","Unidade":"Vila Olímpia","Cidade":"São Paulo","Estado":"SP","Endereço":"R. Gomes de Carvalho, 1715 - Vila Olímpia, São Paulo - SP, 04547-006"},
    {"Sigla":"TBZN","Categoria":"Bar","Vertical":"Bares SP","Marca":"Tatu Bola","Unidade":"Santana","Cidade":"São Paulo","Estado":"SP","Endereço":"Av. Eng. Caetano Álvares, 5680 - Santana, São Paulo - SP, 02413-100"},
    {"Sigla":"TTZPOMP","Categoria":"Bar","Vertical":"Bares SP","Marca":"Tatu Bola","Unidade":"Pompéia","Cidade":"São Paulo","Estado":"SP","Endereço":"R. Barão de Tefé, 137 - Pompeia, São Paulo - SP, 05003-040"}
])


# merge com base procv
df_reservas = df_reservas.merge(
    df_ref,
    on="Sigla",
    how="left",
    validate="m:1"
)

# ajuste formato saída data
df_reservas["Data Evento"] = (
    pd.to_datetime(df_reservas["Data Evento"], errors="coerce")
      .dt.strftime("%d/%m/%Y")
)


# organização ordem BI
final_order = [
    "Sigla","Categoria","Vertical","Marca","Unidade",
    "Cidade","Estado","Endereço",
    "Clientes","Quantidade de Convidados","Data Evento"
]

df_reservas = df_reservas.reindex(columns=final_order)


# validação saída
n_after = len(df_reservas)
print(f"Linhas após merge: {n_after}")

if n_orig != n_after:
    print("Perda de linhas no processo!")

print(
    "Linhas sem Categoria:",
    df_reservas["Categoria"].isna().sum()
)


# exportação base BI
df_reservas.to_excel("reservas_tratadas.xlsx", index=False)

# %% [markdown]
# ## 🛠️ Etapas do Pipeline
#
# #### 1. Leitura da Base
# - Importação de dados a partir de arquivo Excel.
#
# #### 2. Padronização de Unidades
# - Normalização de strings.
# - Mapeamento de nomes completos para siglas padronizadas.
#
# #### 3. Padronização de Colunas
# - Renomeação de campos para um padrão analítico.
# - Reorganização da ordem das colunas.
#
# #### 4. Enriquecimento de Dados
# - Criação de uma base de referência com informações cadastrais.
# - Merge utilizando chave única (Sigla).
#
# #### 5. Validações
# - Verificação de integridade no merge.
# - Checagem de linhas sem categoria.
#
# #### 6. Exportação
# - Geração de base final pronta para consumo em BI.

# %% [markdown]
# ## ✅ Resultado Final
#
# Ao final do processo, a base passa a conter:
#
# - Identificação padronizada da unidade
# - Informações completas de marca e localização
# - Dados organizados para análise temporal e operacional
#
# Essa estrutura facilita análises como:
# - Volume de reservas por unidade
# - Distribuição geográfica
# - Perfil médio de convidados

# %% [markdown]
# ## 📌 Conclusões
#
# Este projeto demonstra uma abordagem prática e escalável para tratamento de dados operacionais, com foco em:
#
# - Qualidade de dados
# - Governança
# - Padronização corporativa
# - Integração com BI
#
# O pipeline pode ser facilmente adaptado para outros contextos que envolvam múltiplas unidades e dados descentralizados.
